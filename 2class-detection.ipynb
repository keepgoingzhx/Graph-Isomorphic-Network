# %%
"""Edge_detection_2class.ipynb
Automatically generated by Colaboratory.
Original file is located at
    https://colab.research.google.com/drive/1GXjpNa289aOJ0mVIx17awm5Cq9-bG47a
"""

#mounting on drive
# from google.colab import drive
# drive.mount('/content/drive',force_remount=True)

import numpy as np
import cv2
import matplotlib.pyplot as plt
# from google.colab.patches import cv2_imshow
import glob

#applying filter on a single image
def apply_filter(filename,filter):

    print("reading file---> "+str(filename))
    img=cv2.imread(filename,cv2.IMREAD_GRAYSCALE)
#img=cv2.resize(img,(250,250))  
#comment out the above line if there is memory issue i.e. need to resize all images to smaller dim

    h, w = img.shape
    print("shape: "+str(h)+" x "+str(w)+"\n")
  # define filters
    horizontal = filter
    vertical = np.transpose(filter)

  # define images with 0s
    newhorizontalImage = np.zeros((h, w))
    newverticalImage = np.zeros((h, w))
    newgradientImage = np.zeros((h, w))

  # offset by 1
    for i in range(1, h - 1):
        for j in range(1, w - 1):
            horizontalGrad = (horizontal[0, 0] * img[i - 1, j - 1]) + \
                          (horizontal[0, 1] * img[i - 1, j]) + \
                          (horizontal[0, 2] * img[i - 1, j + 1]) + \
                          (horizontal[1, 0] * img[i, j - 1]) + \
                          (horizontal[1, 1] * img[i, j]) + \
                          (horizontal[1, 2] * img[i, j + 1]) + \
                          (horizontal[2, 0] * img[i + 1, j - 1]) + \
                          (horizontal[2, 1] * img[i + 1, j]) + \
                          (horizontal[2, 2] * img[i + 1, j + 1])

            newhorizontalImage[i - 1, j - 1] = abs(horizontalGrad)

            verticalGrad = (vertical[0, 0] * img[i - 1, j - 1]) + \
                        (vertical[0, 1] * img[i - 1, j]) + \
                        (vertical[0, 2] * img[i - 1, j + 1]) + \
                        (vertical[1, 0] * img[i, j - 1]) + \
                        (vertical[1, 1] * img[i, j]) + \
                        (vertical[1, 2] * img[i, j + 1]) + \
                        (vertical[2, 0] * img[i + 1, j - 1]) + \
                        (vertical[2, 1] * img[i + 1, j]) + \
                        (vertical[2, 2] * img[i + 1, j + 1])

            newverticalImage[i - 1, j - 1] = abs(verticalGrad)

          # Edge Magnitude
            mag = np.sqrt(pow(horizontalGrad, 2.0) + pow(verticalGrad, 2.0))
            newgradientImage[i - 1, j - 1] = mag

    return newgradientImage

#function for creating all edge-images of a directory
def convert_edge_dir(sourcedir,destdir):
    print("\n\n---reading directory "+sourcedir+"---\n")
    filecnt=1 
    for filename in glob.glob(sourcedir+'/*'):
  #applying Prewitt filter
  #for appyling any other filter change filter value accordingly i.e. the 2nd args for apply_filter()
        imagemat=apply_filter(filename,np.array([[-1,0,1],[-1,0,1],[-1,0,1]]))
        cv2.imwrite(destdir+'/img-'+str(filecnt)+'.jpg',imagemat) #create the edge image and store it to consecutive filenames
        filecnt+=1
    print("\n\n--saved in "+destdir+"--\n")

#function for creating all edge-images under both covid and non-covid directories 
#since 2-class so COVID and NON-COVID present
def convert_edge_all_dir(coviddir,ncoviddir,destdir):

    convert_edge_dir(coviddir,destdir+'/COVID')
    convert_edge_dir(ncoviddir,destdir+'/NON-COVID')
    print("\n---edge detection completed--\n")

# %%
#adjust the source paths accordingly
coviddir='brain/yes' #source path for covid dir
ncoviddir='brain/no' #source path for non-covid dir


#adjust the destination directory accordingly
#directory naming format--> <dataset_name(not necessary conventional)>_edge/<filtername>
destdir='brain/Pretwitt' 

convert_edge_all_dir(coviddir,ncoviddir,destdir)
# Out:
# ---reading directory brain/yes---
#
# reading file---> brain/yes\Y1.jpg
# shape: 218 x 180
#
# reading file---> brain/yes\Y10.jpg
# shape: 360 x 319
#
# reading file---> brain/yes\Y100.JPG
# shape: 348 x 287
#
# reading file---> brain/yes\Y101.jpg
# shape: 336 x 300
#
# reading file---> brain/yes\Y102.jpg
# shape: 630 x 587
#
# reading file---> brain/yes\Y103.jpg
# shape: 993 x 825
#
# reading file---> brain/yes\Y104.jpg
# shape: 890 x 700
#
# reading file---> brain/yes\Y105.jpg
# shape: 246 x 205
#
# reading file---> brain/yes\Y106.jpg
# shape: 253 x 200
#
# reading file---> brain/yes\Y107.jpg
# shape: 512 x 512
#
# reading file---> brain/yes\Y109.JPG
# shape: 279 x 258
#
# reading file---> brain/yes\Y11.jpg
# shape: 369 x 400
#
# reading file---> brain/yes\Y110.jpg
# shape: 237 x 213
#
# reading file---> brain/yes\Y111.JPG
# shape: 324 x 272
#
# reading file---> brain/yes\Y112.JPG
# shape: 366 x 310
#
# reading file---> brain/yes\Y113.JPG
# shape: 312 x 254
#
# reading file---> brain/yes\Y114.JPG
# shape: 249 x 178
#
# reading file---> brain/yes\Y115.JPG
# shape: 298 x 260
#
# reading file---> brain/yes\Y116.JPG
# shape: 269 x 249
#
# reading file---> brain/yes\Y117.JPG
# shape: 310 x 246
#
# reading file---> brain/yes\Y118.JPG
# shape: 351 x 278
#
# reading file---> brain/yes\Y119.JPG
# shape: 331 x 272
#
# reading file---> brain/yes\Y12.jpg
# shape: 500 x 377
#
# reading file---> brain/yes\Y120.JPG
# shape: 245 x 224
#
# reading file---> brain/yes\Y121.JPG
# shape: 355 x 311
#
# reading file---> brain/yes\Y122.JPG
# shape: 352 x 321
#
# reading file---> brain/yes\Y123.JPG
# shape: 283 x 231
#
# reading file---> brain/yes\Y124.jpg
# shape: 359 x 300
#
# reading file---> brain/yes\Y125.jpg
# shape: 431 x 400
#
# reading file---> brain/yes\Y126.JPG
# shape: 355 x 310
#
# reading file---> brain/yes\Y127.JPG
# shape: 370 x 286
#
# reading file---> brain/yes\Y128.JPG
# shape: 309 x 232
#
# reading file---> brain/yes\Y129.JPG
# shape: 334 x 283
#
# reading file---> brain/yes\Y13.jpg
# shape: 325 x 254
#
# reading file---> brain/yes\Y130.JPG
# shape: 354 x 303
#
# reading file---> brain/yes\Y131.JPG
# shape: 348 x 297
#
# reading file---> brain/yes\Y132.JPG
# shape: 351 x 273
#
# reading file---> brain/yes\Y134.JPG
# shape: 316 x 270
#
# reading file---> brain/yes\Y135.JPG
# shape: 336 x 264
#
# reading file---> brain/yes\Y136.JPG
# shape: 303 x 223
#
# reading file---> brain/yes\Y137.JPG
# shape: 291 x 253
#
# reading file---> brain/yes\Y138.JPG
# shape: 350 x 272
#
# reading file---> brain/yes\Y139.jpg
# shape: 300 x 263
#
# reading file---> brain/yes\Y14.jpg
# shape: 300 x 289
#
# reading file---> brain/yes\Y140.jpg
# shape: 325 x 254
#
# reading file---> brain/yes\Y141.JPG
# shape: 355 x 290
#
# reading file---> brain/yes\Y142.jpg
# shape: 586 x 467
#
# reading file---> brain/yes\Y143.jpg
# shape: 380 x 310
#
# reading file---> brain/yes\Y144.JPG
# shape: 318 x 273
#
# reading file---> brain/yes\Y145.jpg
# shape: 347 x 300
#
# reading file---> brain/yes\Y146.JPG
# shape: 173 x 189
#
# reading file---> brain/yes\Y147.jpg
# shape: 380 x 318
#
# reading file---> brain/yes\Y148.jpg
# shape: 450 x 355
#
# reading file---> brain/yes\Y149.jpg
# shape: 244 x 206
#
# reading file---> brain/yes\Y15.jpg
# shape: 380 x 310
#
# reading file---> brain/yes\Y150.jpg
# shape: 879 x 766
#
# reading file---> brain/yes\Y151.JPG
# shape: 342 x 273
#
# reading file---> brain/yes\Y152.JPG
# shape: 351 x 262
#
# reading file---> brain/yes\Y153.jpg
# shape: 256 x 256
#
# reading file---> brain/yes\Y154.JPG
# shape: 340 x 314
#
# reading file---> brain/yes\Y16.JPG
# shape: 360 x 313
#
# reading file---> brain/yes\Y17.jpg
# shape: 300 x 289
#
# reading file---> brain/yes\Y18.JPG
# shape: 354 x 279
#
# reading file---> brain/yes\Y19.JPG
# shape: 359 x 297
#
# reading file---> brain/yes\Y2.jpg
# shape: 212 x 209
#
# reading file---> brain/yes\Y20.jpg
# shape: 300 x 240
#
# reading file---> brain/yes\Y21.jpg
# shape: 247 x 204
#
# reading file---> brain/yes\Y22.jpg
# shape: 380 x 294
#
# reading file---> brain/yes\Y23.JPG
# shape: 277 x 272
#
# reading file---> brain/yes\Y24.jpg
# shape: 1024 x 1024
#
# reading file---> brain/yes\Y25.jpg
# shape: 630 x 504
#
# reading file---> brain/yes\Y26.jpg
# shape: 630 x 628
#
# reading file---> brain/yes\Y27.jpg
# shape: 630 x 630
#
# reading file---> brain/yes\Y28.jpg
# shape: 630 x 630
#
# reading file---> brain/yes\Y29.jpg
# shape: 630 x 630
#
# reading file---> brain/yes\Y3.jpg
# shape: 519 x 456
#
# reading file---> brain/yes\Y30.jpg
# shape: 325 x 300
#
# reading file---> brain/yes\Y31.jpg
# shape: 294 x 250
#
# reading file---> brain/yes\Y32.jpg
# shape: 555 x 526
#
# reading file---> brain/yes\Y33.jpg
# shape: 512 x 512
#
# reading file---> brain/yes\Y34.jpg
# shape: 380 x 310
#
# reading file---> brain/yes\Y35.jpg
# shape: 446 x 450
#
# reading file---> brain/yes\Y36.JPG
# shape: 251 x 204
#
# reading file---> brain/yes\Y37.jpg
# shape: 360 x 319
#
# reading file---> brain/yes\Y38.jpg
# shape: 325 x 300
#
# reading file---> brain/yes\Y39.jpg
# shape: 278 x 236
#
# reading file---> brain/yes\Y4.jpg
# shape: 225 x 225
#
# reading file---> brain/yes\Y40.JPG
# shape: 365 x 306
#
# reading file---> brain/yes\Y41.jpg
# shape: 1427 x 1275
#
# reading file---> brain/yes\Y42.jpg
# shape: 210 x 200
#
# reading file---> brain/yes\Y43.JPG
# shape: 349 x 292
#
# reading file---> brain/yes\Y44.JPG
# shape: 337 x 293
#
# reading file---> brain/yes\Y45.JPG
# shape: 340 x 291
#
# reading file---> brain/yes\Y46.jpg
# shape: 929 x 634
#
# reading file---> brain/yes\Y47.JPG
# shape: 355 x 320
#
# reading file---> brain/yes\Y48.jpg
# shape: 960 x 781
#
# reading file---> brain/yes\Y49.JPG
# shape: 307 x 271
#
# reading file---> brain/yes\Y5.JPG
# shape: 324 x 278
#
# reading file---> brain/yes\Y50.JPG
# shape: 350 x 315
#
# reading file---> brain/yes\Y51.jpg
# shape: 938 x 911
#
# reading file---> brain/yes\Y52.jpg
# shape: 938 x 911
#
# reading file---> brain/yes\Y53.jpg
# shape: 219 x 230
#
# reading file---> brain/yes\Y54.jpg
# shape: 325 x 300
#
# reading file---> brain/yes\Y55.jpg
# shape: 620 x 620
#
# reading file---> brain/yes\Y56.jpg
# shape: 239 x 211
#
# reading file---> brain/yes\Y57.JPG
# shape: 352 x 281
#
# reading file---> brain/yes\Y58.JPG
# shape: 340 x 314
#
# reading file---> brain/yes\Y59.JPG
# shape: 270 x 229
#
# reading file---> brain/yes\Y6.jpg
# shape: 938 x 911
#
# reading file---> brain/yes\Y60.jpg
# shape: 255 x 197
#
# reading file---> brain/yes\Y61.jpg
# shape: 520 x 433
#
# reading file---> brain/yes\Y62.jpg
# shape: 294 x 250
#
# reading file---> brain/yes\Y63.JPG
# shape: 295 x 283
#
# reading file---> brain/yes\Y64.jpg
# shape: 251 x 201
#
# reading file---> brain/yes\Y65.JPG
# shape: 243 x 205
#
# reading file---> brain/yes\Y66.JPG
# shape: 340 x 288
#
# reading file---> brain/yes\Y67.JPG
# shape: 233 x 215
#
# reading file---> brain/yes\Y68.JPG
# shape: 338 x 283
#
# reading file---> brain/yes\Y69.jpg
# shape: 630 x 504
#
# reading file---> brain/yes\Y7.jpg
# shape: 456 x 374
#
# reading file---> brain/yes\Y70.jpg
# shape: 325 x 300
#
# reading file---> brain/yes\Y71.JPG
# shape: 349 x 300
#
# reading file---> brain/yes\Y72.jpg
# shape: 256 x 197
#
# reading file---> brain/yes\Y73.jpg
# shape: 290 x 250
#
# reading file---> brain/yes\Y74.jpg
# shape: 620 x 620
#
# reading file---> brain/yes\Y75.JPG
# shape: 338 x 264
#
# reading file---> brain/yes\Y76.jpg
# shape: 442 x 353
#
# reading file---> brain/yes\Y77.jpg
# shape: 353 x 300
#
# reading file---> brain/yes\Y78.jpg
# shape: 251 x 201
#
# reading file---> brain/yes\Y79.jpg
# shape: 431 x 400
#
# reading file---> brain/yes\Y8.jpg
# shape: 446 x 450
#
# reading file---> brain/yes\Y80.JPG
# shape: 349 x 278
#
# reading file---> brain/yes\Y81.jpg
# shape: 234 x 216
#
# reading file---> brain/yes\Y82.jpg
# shape: 223 x 226
#
# reading file---> brain/yes\Y83.jpg
# shape: 236 x 213
#
# reading file---> brain/yes\Y84.JPG
# shape: 331 x 260
#
# reading file---> brain/yes\Y85.JPG
# shape: 308 x 244
#
# reading file---> brain/yes\Y86.JPG
# shape: 350 x 272
#
# reading file---> brain/yes\Y87.JPG
# shape: 315 x 289
#
# reading file---> brain/yes\Y88.JPG
# shape: 338 x 248
#
# reading file---> brain/yes\Y89.JPG
# shape: 286 x 241
#
# reading file---> brain/yes\Y9.jpg
# shape: 630 x 630
#
# reading file---> brain/yes\Y90.jpg
# shape: 512 x 512
#
# reading file---> brain/yes\Y91.jpg
# shape: 1280 x 1061
#
# reading file---> brain/yes\Y92.jpg
# shape: 260 x 194
#
# reading file---> brain/yes\Y93.JPG
# shape: 344 x 279
#
# reading file---> brain/yes\Y94.JPG
# shape: 355 x 294
#
# reading file---> brain/yes\Y95.jpg
# shape: 225 x 225
#
# reading file---> brain/yes\Y96.jpg
# shape: 938 x 864
#
# reading file---> brain/yes\Y97.JPG
# shape: 355 x 272
#
# reading file---> brain/yes\Y98.JPG
# shape: 323 x 276
#
# reading file---> brain/yes\Y99.JPG
# shape: 357 x 283
#
#
#
# --saved in brain/Pretwitt/COVID--
#
#
#
# ---reading directory brain/no---
#
# reading file---> brain/no\N (100).jpg
# shape: 251 x 201
# reading file---> brain/no\N (101).jpg
# shape: 251 x 201
#
# reading file---> brain/no\N (102).jpg
# shape: 252 x 200
#
# reading file---> brain/no\N (103).jpg
# shape: 243 x 207
#
# reading file---> brain/no\N (104).jpg
# shape: 252 x 200
#
# reading file---> brain/no\N (105).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (106).jpg
# shape: 217 x 232
#
# reading file---> brain/no\N (107).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (108).jpg
# shape: 238 x 212
#
# reading file---> brain/no\N (109).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (110).jpg
# shape: 234 x 215
#
# reading file---> brain/no\N (111).jpg
# shape: 250 x 201
#
# reading file---> brain/no\N (112).jpg
# shape: 250 x 201
#
# reading file---> brain/no\N (113).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (114).jpg
# shape: 222 x 227
#
# reading file---> brain/no\N (115).jpg
# shape: 251 x 201
#
# reading file---> brain/no\N (116).jpg
# shape: 197 x 177
#
# reading file---> brain/no\N (117).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (118).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (119).jpg
# shape: 214 x 235
#
# reading file---> brain/no\N (120).jpg
# shape: 221 x 228
#
# reading file---> brain/no\N (121).jpg
# shape: 200 x 200
#
# reading file---> brain/no\N (122).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (123).jpg
# shape: 194 x 259
#
# reading file---> brain/no\N (124).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (125).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (126).jpg
# shape: 231 x 218
#
# reading file---> brain/no\N (127).jpg
# shape: 231 x 218
#
# reading file---> brain/no\N (128).jpg
# shape: 217 x 232
#
# reading file---> brain/no\N (129).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (130).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (131).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (132).jpg
# shape: 213 x 236
#
# reading file---> brain/no\N (133).jpg
# shape: 221 x 228
#
# reading file---> brain/no\N (134).jpg
# shape: 244 x 206
#
# reading file---> brain/no\N (135).jpg
# shape: 168 x 300
#
# reading file---> brain/no\N (136).jpg
# shape: 168 x 300
#
# reading file---> brain/no\N (137).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (138).jpg
# shape: 198 x 150
#
# reading file---> brain/no\N (139).jpg
# shape: 225 x 225
#
# reading file---> brain/no\N (140).jpg
# shape: 183 x 275
#
# reading file---> brain/no\N (141).jpg
# shape: 201 x 173
#
# reading file---> brain/no\N (142).jpg
# shape: 201 x 173
#
# reading file---> brain/no\N (143).jpg
# shape: 192 x 192
#
# reading file---> brain/no\N (144).jpg
# shape: 168 x 300
#
# reading file---> brain/no\N (145).jpg
# shape: 664 x 550
#
# reading file---> brain/no\N (146).jpg
# shape: 680 x 680
#
# reading file---> brain/no\N (147).jpg
# shape: 512 x 512
#
# reading file---> brain/no\N (148).jpg
# shape: 454 x 442
#
# reading file---> brain/no\N (149).jpg
# shape: 725 x 728
#
# reading file---> brain/no\N (150).jpg
# shape: 400 x 393
#
# reading file---> brain/no\N (151).jpg
# shape: 400 x 393
#
# reading file---> brain/no\N (152).jpg
# shape: 1024 x 1024
#
# reading file---> brain/no\N (153).jpg
# shape: 630 x 630
#
# reading file---> brain/no\N (154).jpg
# shape: 417 x 428
#
# reading file---> brain/no\N (155).jpg
# shape: 530 x 380
#
# reading file---> brain/no\N (156).jpg
# shape: 630 x 630
#
# reading file---> brain/no\N (157).jpg
# shape: 750 x 750
#
# reading file---> brain/no\N (158).jpg
# shape: 442 x 409
#
# reading file---> brain/no\N (159).jpg
# shape: 301 x 275
#
# reading file---> brain/no\N (160).jpg
# shape: 537 x 472
#
# reading file---> brain/no\N (161).jpg
# shape: 540 x 504
#
# reading file---> brain/no\N (162).jpg
# shape: 449 x 359
#
# reading file---> brain/no\N (163).jpg
# shape: 442 x 442
#
# reading file---> brain/no\N (164).jpg
# shape: 393 x 350
#
# reading file---> brain/no\N (165).jpg
# shape: 614 x 630
#
# reading file---> brain/no\N (166).jpg
# shape: 442 x 442
#
# reading file---> brain/no\N (167).jpg
# shape: 444 x 468
#
# reading file---> brain/no\N (168).jpg
# shape: 361 x 642
#
# reading file---> brain/no\N (169).jpg
# shape: 474 x 356
#
# reading file---> brain/no\N (170).JPG
# shape: 282 x 230
#
# reading file---> brain/no\N (171).JPG
# shape: 338 x 276
#
# reading file---> brain/no\N (172).jpg
# shape: 442 x 442
#
# reading file---> brain/no\N (173).JPG
# shape: 326 x 276
#
# reading file---> brain/no\N (174).jpg
# shape: 442 x 441
#
# reading file---> brain/no\N (175).JPG
# shape: 264 x 210
#
# reading file---> brain/no\N (176).JPG
# shape: 262 x 227
#
# reading file---> brain/no\N (177).JPG
# shape: 248 x 208
#
# reading file---> brain/no\N (96).jpg
# shape: 236 x 214
#
# reading file---> brain/no\N (97).jpg
# shape: 217 x 232
#
# reading file---> brain/no\N (98).jpg
# shape: 257 x 196
#
# reading file---> brain/no\N (99).jpg
# shape: 259 x 194
#
# reading file---> brain/no\N1.jpg
# shape: 225 x 225
#
# reading file---> brain/no\N2.jpg
# shape: 340 x 339
#
# reading file---> brain/no\N3.jpg
# shape: 280 x 420
#
# reading file---> brain/no\N4.jpg
# shape: 275 x 220
#
# reading file---> brain/no\N5.jpg
# shape: 275 x 220
#
# reading file---> brain/no\N6.jpg
# shape: 225 x 225
#
# reading file---> brain/no\N7.jpg
# shape: 242 x 208
#
# reading file---> brain/no\N8.jpg
# shape: 242 x 208
#
# reading file---> brain/no\Ny1.jpg
# shape: 512 x 512
#
# reading file---> brain/no\Ny2.jpg
# shape: 929 x 634
#
#
#
# --saved in brain/Pretwitt/NON-COVID--
#
#
# ---edge detection completed--
